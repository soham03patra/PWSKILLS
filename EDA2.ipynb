# %% [markdown]
# ## Q(1)

# %%
#importing basics libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_excel('flight_price.xlsx')
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.shape
# Out:
# (10683, 11)

# %% [markdown]
# ## Q(2)

# %%
import matplotlib.pyplot as plt

# Assuming flight_data is your DataFrame and 'flight_prices' is the column
flight_prices = df['Price']

# Create a histogram
plt.figure(figsize=(10, 6))
plt.hist(flight_prices, bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Flight Prices')
plt.xlabel('Flight Prices')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# ## Q(3)

# %%
# Assuming flight_data is your DataFrame and 'flight_prices' is the column
flight_prices = df['Price']

# Calculate range, minimum, and maximum prices
price_range = flight_prices.max() - flight_prices.min()
min_price = flight_prices.min()
max_price = flight_prices.max()

print(f"Range of prices: {price_range}")
print(f"Minimum price: {min_price}")
print(f"Maximum price: {max_price}")
# Out:
# Range of prices: 77753
# Minimum price: 1759
# Maximum price: 79512

# %%
price_statistics = flight_prices.describe()
print(price_statistics)
# Out:
# count    10683.000000
# mean      9087.064121
# std       4611.359167
# min       1759.000000
# 25%       5277.000000
# 50%       8372.000000
# 75%      12373.000000
# max      79512.000000
# Name: Price, dtype: float64

# %% [markdown]
# ## Q(4)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming flight_data is your DataFrame
# Replace 'Airline' and 'Flight Prices' with the actual column names in your dataset
sns.set(style="whitegrid")
plt.figure(figsize=(12, 8))

sns.boxplot(x='Airline', y='Price', data=df, palette='viridis')
plt.title('Flight Prices by Airline')
plt.xlabel('Airline')
plt.ylabel('Flight Prices')

plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ## Q(5)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming flight_data is your DataFrame
# Replace 'Flight Prices' with the actual column name in your dataset
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))

sns.boxplot(x=df['Price'], color='skyblue')
plt.title('Boxplot of Flight Prices')
plt.xlabel('Flight Prices')

plt.show()

# %% [markdown]
# ## Q(6)

# %% [markdown]
# Identifying the peak travel season involves analyzing various features that can provide insights into when flight prices tend to be higher or lower. Here are some features you might want to analyze:
#
# 1. **Month or Season:**
#    - Analyze how flight prices vary across different months or seasons. There might be specific months or seasons when prices are consistently higher due to holidays, events, or weather conditions.
#
# 2. **Day of the Week:**
#    - Explore whether flight prices are influenced by the day of the week. For example, weekends or specific weekdays might have higher demand and, consequently, higher prices.
#
# 3. **Time of Day:**
#    - Investigate whether there are patterns in flight prices based on the time of day. Red-eye flights or flights during peak hours may have different pricing patterns.
#
# 4. **Holiday Periods:**
#    - Identify the impact of holidays on flight prices. Prices tend to rise during peak holiday seasons due to increased demand.
#
# 5. **Advance Booking:**
#    - Analyze if there's a correlation between the lead time for booking and the price of flights. In some cases, booking well in advance might lead to lower prices.
#
# 6. **Airline and Route:**
#    - Investigate whether specific airlines or routes have different seasonal pricing patterns. Certain airlines might offer promotions during specific times of the year.
#
# 7. **Economic Factors:**
#    - Consider external economic factors that might influence travel demand, such as economic downturns or peak business travel seasons.
#
# ### Analytical Steps:
#
# 1. **Descriptive Statistics:**
#    - Calculate summary statistics for flight prices across different months, days of the week, and times of the day.
#
# 2. **Data Visualization:**
#    - Create visualizations such as line charts, bar charts, or heatmaps to illustrate the trends in flight prices over time and across different factors.
#
# 3. **Statistical Tests:**
#    - Conduct statistical tests to identify significant differences in flight prices between different periods. For example, t-tests or ANOVA tests can be used to compare means.
#
# 4. **Time Series Analysis:**
#    - If you have a time series dataset, perform time series analysis to identify recurring patterns or trends in flight prices.
#
# ### Presentation to Your Boss:
#
# 1. **Executive Summary:**
#    - Begin with a concise executive summary outlining the purpose of the analysis and its relevance to the travel agency.
#
# 2. **Key Findings:**
#    - Present the key findings related to peak travel seasons, including the months, days of the week, and times of the day when flight prices are highest.
#
# 3. **Visualizations:**
#    - Share visually appealing and easily interpretable charts and graphs to illustrate the identified trends. Consider a line chart for time-based trends and bar charts for categorical factors.
#
# 4. **Recommendations:**
#    - Provide recommendations based on the analysis, such as suggestions for optimizing pricing strategies, marketing efforts, or offering promotions during specific periods.
#
# 5. **Next Steps:**
#    - Discuss potential follow-up analyses or actions to further optimize the travel agency's strategies based on the identified peak travel seasons.
#
# Remember to communicate your findings in a clear and actionable manner, keeping in mind the goals and interests of the travel agency. Visualizations and concise summaries are essential for making the analysis accessible to stakeholders.

# %% [markdown]
# ## Q(7)

# %% [markdown]
# As a data analyst for a flight booking website, you would likely analyze various features to identify trends in flight prices. Here are some key features to consider and the corresponding visualizations you can use to present your findings:
#
# ### Features to Analyze:
#
# 1. **Time Trends:**
#    - **Feature:** Date or time of flight booking.
#    - **Visualization:** Time series plot showing the trend in flight prices over time.
#
# 2. **Seasonal Trends:**
#    - **Feature:** Month or season of the year.
#    - **Visualization:** Seasonal decomposition plot or boxplot to highlight monthly or seasonal variations in flight prices.
#
# 3. **Day of the Week Trends:**
#    - **Feature:** Day of the week.
#    - **Visualization:** Boxplot or line chart to show how flight prices vary across different days of the week.
#
# 4. **Advance Booking Trends:**
#    - **Feature:** Lead time between booking and departure.
#    - **Visualization:** Scatter plot or line chart to visualize the relationship between lead time and flight prices.
#
# 5. **Route or Destination Trends:**
#    - **Feature:** Flight route or destination.
#    - **Visualization:** Heatmap or bar chart to show the average prices for different routes or destinations.
#
# 6. **Airline Trends:**
#    - **Feature:** Airline.
#    - **Visualization:** Grouped bar chart or violin plot to compare the average prices of different airlines.
#
# 7. **Flight Class Trends:**
#    - **Feature:** Flight class (e.g., economy, business).
#    - **Visualization:** Boxplot or bar chart to compare the average prices across different classes.
#
# 8. **Holiday or Event Trends:**
#    - **Feature:** Presence of holidays or major events.
#    - **Visualization:** Annotated time series plot to highlight periods with holidays or events.
#
# ### Visualizations to Present Findings:
#
# 1. **Time Series Plot:**
#    - Display the overall trend in flight prices over time, allowing your team to see any long-term patterns or changes.
#
# 2. **Seasonal Decomposition Plot:**
#    - Highlight seasonal patterns, helping your team understand how flight prices vary across different months or seasons.
#
# 3. **Boxplots:**
#    - Use boxplots to visualize the distribution of flight prices for different categories, such as days of the week, flight classes, or airlines.
#
# 4. **Scatter Plots:**
#    - Show the relationship between lead time and flight prices, revealing whether booking well in advance correlates with lower prices.
#
# 5. **Heatmaps:**
#    - Present a heatmap to compare flight prices for different routes or destinations, allowing your team to identify popular and potentially expensive routes.
#
# 6. **Bar Charts:**
#    - Use bar charts to compare average prices for different airlines, destinations, or other categorical variables.
#
# 7. **Violin Plots:**
#    - Combine the benefits of boxplots and kernel density plots to compare the distribution of flight prices across different airlines.
#
# 8. **Annotated Time Series Plot:**
#    - Annotate holidays or major events on a time series plot to highlight how these factors may influence flight prices.
#
# ### Presentation Tips:
#
# 1. **Clear Titles and Labels:**
#    - Ensure that your visualizations have clear titles and labels to convey the information accurately.
#
# 2. **Interactivity:**
#    - If possible, provide interactive visualizations to allow your team to explore the data more deeply.
#
# 3. **Narrative Storytelling:**
#    - Present your findings in a logical sequence, guiding your team through the trends and insights you've identified.
#
# 4. **Actionable Insights:**
#    - Conclude your presentation with actionable insights, such as recommendations for pricing strategies, marketing efforts, or user communication based on the identified trends.
#
# By analyzing these features and using appropriate visualizations, you can effectively communicate trends in flight prices to your team and help inform strategic decisions for the flight booking website.

# %% [markdown]
# ## Q(8)

# %% [markdown]
# As a data scientist working for an airline company, identifying factors that affect flight prices is crucial for optimizing pricing strategies and making informed business decisions. Here are the key features you might analyze and how you could present your findings to the management team:
#
# ### Features to Analyze:
#
# 1. **Route and Distance:**
#    - Analyze how the flight route and distance impact prices. Longer routes or popular destinations may have higher prices.
#
# 2. **Airline and Service Class:**
#    - Investigate the impact of different airlines and service classes (economy, business, first class) on flight prices.
#
# 3. **Time Factors:**
#    - Explore the influence of departure and arrival times, day of the week, month, and season on flight prices.
#
# 4. **Advance Booking:**
#    - Analyze how the lead time between booking and departure affects flight prices.
#
# 5. **Holiday and Event Periods:**
#    - Investigate whether flight prices are influenced by holidays or major events.
#
# 6. **Supply and Demand Dynamics:**
#    - Consider the overall demand for flights and the airline's capacity on specific routes.
#
# 7. **Competitor Prices:**
#    - Explore how prices offered by competitors impact your own pricing strategy.
#
# 8. **Economic Factors:**
#    - Assess the impact of economic conditions, fuel prices, and other macroeconomic factors on flight prices.
#
# ### Analysis and Presentation:
#
# 1. **Descriptive Statistics:**
#    - Begin with summary statistics for each key feature, highlighting mean, median, and variability.
#
# 2. **Correlation Analysis:**
#    - Use correlation matrices or heatmaps to identify relationships between flight prices and other features.
#
# 3. **Regression Analysis:**
#    - Perform regression analysis to quantify the impact of different factors on flight prices. This could include linear regression or more complex models.
#
# 4. **Visualization:**
#    - Create visualizations to illustrate the relationships. For example, scatter plots, line charts, or boxplots can be effective.
#
# 5. **Feature Importance:**
#    - Use techniques like feature importance from machine learning models to identify the most influential factors.
#
# 6. **Statistical Tests:**
#    - Conduct statistical tests to assess the significance of differences in flight prices across categories (e.g., airlines, service classes).
#
# ### Presentation to the Management Team:
#
# 1. **Executive Summary:**
#    - Provide a concise executive summary outlining the purpose, key findings, and potential implications.
#
# 2. **Key Findings:**
#    - Present the main factors affecting flight prices and their relative importance.
#
# 3. **Visualizations:**
#    - Showcase visualizations that effectively communicate the relationships between flight prices and different features. Use clear labels and annotations.
#
# 4. **Impact Assessment:**
#    - Discuss the quantitative impact of each factor on flight prices. For example, how much does an additional hour in flight duration impact the price?
#
# 5. **Recommendations:**
#    - Offer actionable recommendations based on the findings. This could include suggestions for pricing strategies, marketing efforts, or operational adjustments.
#
# 6. **Limitations and Assumptions:**
#    - Clearly communicate any limitations or assumptions in the analysis to provide context for the results.
#
# 7. **Q&A Session:**
#    - Allow time for questions and discussions. Be prepared to explain the methodology, results, and potential next steps.
#
# 8. **Report and Documentation:**
#    - Provide a detailed report with documentation of the analysis, including code, data sources, and assumptions made during the process.
#
# By conducting a thorough analysis of these factors and presenting the findings in a clear and actionable manner, you can contribute valuable insights to the airline's decision-making process and help optimize pricing strategies for increased competitiveness and profitability.

# %% [markdown]
# ## Q(9)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# ## Q(10)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming the columns in your dataset include 'Category' and 'Rating'
# Replace these with the actual column names in your dataset

# Create a boxplot
plt.figure(figsize=(12, 8))
sns.boxplot(x='Category', y='Rating', data=df, palette='viridis')
plt.title('App Ratings by Category')
plt.xlabel('App Category')
plt.ylabel('App Rating')

plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ## Q(11)

# %%
import pandas as pd

# Assuming 'google_playstore_df' is your DataFrame loaded from the Google Playstore dataset
# Replace this with the actual name of your DataFrame

# Check for missing values
missing_values = df.isnull().sum()

# Display the count of missing values for each column
print("Missing Values:")
print(missing_values)

# Display the percentage of missing values for each column
percentage_missing = (missing_values / len(df)) * 100
print("\nPercentage of Missing Values:")
print(percentage_missing)
# Out:
# Missing Values:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64
#
# Percentage of Missing Values:
# App                0.000000
# Category           0.000000
# Rating            13.596532
# Reviews            0.000000
# Size               0.000000
# Installs           0.000000
# Type               0.009224
# Price              0.000000
# Content Rating     0.009224
# Genres             0.000000
# Last Updated       0.000000
# Current Ver        0.073794
# Android Ver        0.027673
# dtype: float64

# %%
# Impute missing values in the 'Rating' column with the mean value
df['Rating'].fillna(df['Rating'].mean(), inplace=True)

# %% [markdown]
# ## Q(12)

# %%
import matplotlib.pyplot as plt

# Assuming 'google_playstore_df' is your DataFrame with columns 'Size' and 'Rating'
# Replace these with the actual column names in your dataset

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Size'],df['Rating'], alpha=0.5, color='g')
plt.title('Relationship between App Size and Rating')
plt.xlabel('App Size')
plt.ylabel('App Rating')

plt.show()

# %% [markdown]
# ## Q(13)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'google_playstore_df' is your DataFrame with columns 'Type' and 'Price'
# Replace these with the actual column names in your dataset

# Create a bar chart for average prices by app type
plt.figure(figsize=(10, 6))
sns.barplot(x='App', y='Price', data=df, ci=None, estimator='mean', palette='viridis')
plt.title('Average Prices by App Type')
plt.xlabel('App Type')
plt.ylabel('Average Price')

plt.show()

# %% [markdown]
# ## Q(14)

# %%
import pandas as pd

# Assuming 'google_playstore_df' is your DataFrame with a column 'Installs'
# Replace these with the actual column names in your dataset

# Create a frequency table for app installs
install_counts = df['Installs'].value_counts()

# Sort the frequency table in descending order
sorted_install_counts = install_counts.sort_values(ascending=False)

# Display the top 10 most popular apps
top_10_apps = sorted_install_counts.head(10)
print("Top 10 Most Popular Apps by Number of Installs:")
print(top_10_apps)
# Out:
# Top 10 Most Popular Apps by Number of Installs:
# 1,000,000+     1579
# 10,000,000+    1252
# 100,000+       1169
# 10,000+        1054
# 1,000+          907
# 5,000,000+      752
# 100+            719
# 500,000+        539
# 50,000+         479
# 5,000+          477
# Name: Installs, dtype: int64

# %% [markdown]
# ## Q(15)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Analyze app categories
category_counts = df['Category'].value_counts()
average_ratings_by_category = df.groupby('Category')['Rating'].mean()
average_installs_by_category =df.groupby('Category')['Installs'].mean()

# Create visualizations
plt.figure(figsize=(14, 8))
sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')
plt.title('Number of Apps in Each Category')
plt.xlabel('App Category')
plt.ylabel('Number of Apps')
plt.xticks(rotation=90)
plt.show()

plt.figure(figsize=(14, 8))
sns.barplot(x=average_ratings_by_category.index, y=average_ratings_by_category.values, palette='viridis')
plt.title('Average Ratings by Category')
plt.xlabel('App Category')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)
plt.show()

plt.figure(figsize=(14, 8))
sns.barplot(x=average_installs_by_category.index, y=average_installs_by_category.values, palette='viridis')
plt.title('Average Installs by Category')
plt.xlabel('App Category')
plt.ylabel('Average Installs')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Q(16)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'google_playstore_df' is your DataFrame with relevant columns
# Replace these with the actual column names in your dataset

# Analyze the top developers
top_developers = df['Developer'].value_counts().head(10).index

# Create a bar chart for the number of installs
plt.figure(figsize=(12, 6))
sns.barplot(x='Installs', y='Developer', data=df[df['Developer'].isin(top_developers)])
plt.title('Top Developers by Number of Installs')
plt.xlabel('Number of Installs')
plt.ylabel('Developer')
plt.show()

# Create a bar chart for average ratings
plt.figure(figsize=(12, 6))
sns.barplot(x='Rating', y='Developer', data=df[df['Developer'].isin(top_developers)])
plt.title('Top Developers by Average Ratings')
plt.xlabel('Average Rating')
plt.ylabel('Developer')
plt.show()

# %% [markdown]
# ## Q(17)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'google_playstore_df' is your DataFrame with relevant columns
# Replace these with the actual column names in your dataset

# Convert 'Last Updated' to datetime format
df['Last Updated'] = pd.to_datetime(google_playstore_df['Last Updated'])

# Create time series plots for installs and ratings
plt.figure(figsize=(14, 6))
sns.lineplot(x='Last Updated', y='Installs', data=df, ci=None)
plt.title('Trend in Number of Installs Over Time')
plt.xlabel('Last Updated')
plt.ylabel('Number of Installs')
plt.show()

plt.figure(figsize=(14, 6))
sns.lineplot(x='Last Updated', y='Rat
