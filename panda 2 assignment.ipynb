# %%
import pandas as pd

# %%
df = pd.read_csv("services.csv")

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
df.describe()
# Out:
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# std     6.78233     6.711444         NaN
# min     1.00000     1.000000         NaN
# 25%     6.50000     6.500000         NaN
# 50%    12.00000    12.000000         NaN
# 75%    17.50000    17.500000         NaN
# max    23.00000    22.000000         NaN

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df.dropna(axis=1)
# Out:
#     id  location_id                                application_process  \
# 0    1            1                         Walk in or apply by phone.
# 1    2            2                 Apply by phone for an appointment.
# 2    3            3        Phone for information (403-4300 Ext. 4322).
# 3    4            4                                    Apply by phone.
# 4    5            5                             Phone for information.
# 5    6            6  Walk in or apply by phone for membership appli...
# 6    7            7  Apply by phone or be referred by a doctor, soc...
# 7    8            8                                    Apply by phone.
# 8    9            9  Walk in. Proof of residency in California requ...
# 9   10           10  Walk in. Proof of California residency to rece...
# 10  11           11  Walk in. Proof of California residency require...
# 11  12           12  Walk in or apply by phone, email or webpage re...
# ...

# %%
print("original index data frame")
df = pd.DataFrame({
"a":[1,2,3,4],
"b":[5,6,7,8],
"c":[9,10,11,12]    
})

print(df)

print("")

print("reindex data frame")

l=[1,3,5,7]
df1 = pd.DataFrame({
"a":[1,2,3,4],
"b":[5,6,7,8],
"c":[9,10,11,12]    
},index =l )

print(df1)
# Out:
# original index data frame
#    a  b   c
# 0  1  5   9
# 1  2  6  10
# 2  3  7  11
# 3  4  8  12
#
# reindex data frame
#    a  b   c
# 1  1  5   9
# 3  2  6  10
# 5  3  7  11
# 7  4  8  12

# %%
df = pd.DataFrame({'Values' : [10, 20, 30, 40, 50]})

# %%
df
# Out:
#    Values
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50

# %%
def calculate(x):
    value = x['Values'][0:3]
    total_sum = sum(value)
    print(total_sum)

# %%
calculate(df)
# Out:
# 60

# %%
text = "hi my name is soham patra"
text.split()
# Out:
# ['hi', 'my', 'name', 'is', 'soham', 'patra']

# %%
len(text.split())
# Out:
# 6

# %%
 df = pd.DataFrame({"Text":["hi my name is soham patra","i am learning data science"]})

# %%
df["word_len"] = df['Text'].apply(lambda x :len(x.split()))

# %%
df
# Out:
#                          Text  word_len
# 0   hi my name is soham patra         6
# 1  i am learning data science         5

# %% [markdown]
# ##### 5)
#
# DataFrame.size() returns the total number of elements (cells) in the DataFrame.
# DataFrame.shape() returns a tuple representing the dimensions of the DataFrame (number of rows and columns).

# %%
data = {'A': [1, 2, 3],
        'B': [4, 5, 6]}
df = pd.DataFrame(data)

print("DataFrame size:", df.size)
print("DataFrame shape:", df.shape)
# Out:
# DataFrame size: 6
# DataFrame shape: (3, 2)

# %% [markdown]
# #### 6)
#
# pd.read_excel is the function of pandas  we use to read an excel file.

# %%
def extract_username(df):
    df['Username'] = df['Email'].str.split('@').str.get(0)
    return df

# %%
data = {'Email': ['john.doe@example.com', 'jane.smith@example.com']}
df = pd.DataFrame(data)


df = extract_username(df)


print(df)
# Out:
#                     Email    Username
# 0    john.doe@example.com    john.doe
# 1  jane.smith@example.com  jane.smith

# %%
df
# Out:
#                     Email    Username
# 0    john.doe@example.com    john.doe
# 1  jane.smith@example.com  jane.smith

# %%
def select_rows(df):
    selected_rows = df[(df['A'] > 5) & (df['B'] < 10)]
    return selected_rows

# %%
data = {'A': [3, 1, 7, 6, 3, 5, 4],
        'B': [5, 8, 2, 9, 2, 4, 9],
        'C': [1, 2, 3, 4, 5, 1, 2]}
df = pd.DataFrame(data)

selected_df = select_rows(df)

print(df)
print("")
print(selected_df)
# Out:
#    A  B  C
# 0  3  5  1
# 1  1  8  2
# 2  7  2  3
# 3  6  9  4
# 4  3  2  5
# 5  5  4  1
# 6  4  9  2
#
#    A  B  C
# 2  7  2  3
# 3  6  9  4

# %%
def calculate_statistics(df):
    mean_value = df['Values'].mean()
    median_value = df['Values'].median()
    std_value = df['Values'].std()
    return mean_value, median_value, std_value

# %%
data = {'Values': [5, 8, 2, 9, 2, 4, 9]}
df = pd.DataFrame(data)

mean, median, std = calculate_statistics(df)

print("Mean:", mean)
print("Median:", median)
print("Standard Deviation:", std)
# Out:
# Mean: 5.571428571428571
# Median: 5.0
# Standard Deviation: 3.1014589500826255

# %%
def calculate_moving_average(df):
    df['MovingAverage'] = df['Sales'].rolling(window=7).mean()
    return df

# %%
data = {'Sales': [10, 12, 15, 11, 9, 13, 14, 16, 18, 20, 17, 19]}
dates = pd.date_range(start='2023-07-09', periods=12)
df = pd.DataFrame({'Date': dates, 'Sales': data['Sales']})


df = calculate_moving_average(df)


print(df)
# Out:
#          Date  Sales  MovingAverage
# 0  2023-07-09     10            NaN
# 1  2023-07-10     12            NaN
# 2  2023-07-11     15            NaN
# 3  2023-07-12     11            NaN
# 4  2023-07-13      9            NaN
# 5  2023-07-14     13            NaN
# 6  2023-07-15     14      12.000000
# 7  2023-07-16     16      12.857143
# 8  2023-07-17     18      13.714286
# 9  2023-07-18     20      14.428571
# 10 2023-07-19     17      15.285714
# 11 2023-07-20     19      16.714286

# %%
def add_weekday_column(df):
    df['Weekday'] = df['Date'].dt.strftime('%A')
    return df

# %%
dates = pd.to_datetime(['2023-07-09', '2023-07-10', '2023-07-11', '2023-07-12', '2023-07-13'])
df = pd.DataFrame({'Date': dates})

df = add_weekday_column(df)

print(df)
# Out:
#         Date    Weekday
# 0 2023-07-09     Sunday
# 1 2023-07-10     Monday
# 2 2023-07-11    Tuesday
# 3 2023-07-12  Wednesday
# 4 2023-07-13   Thursday

# %%
def select_rows_within_date_range(df):
    start_date = pd.to_datetime('2023-01-01')
    end_date = pd.to_datetime('2023-01-31')
    selected_rows = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]
    return selected_rows

# %%
dates = pd.date_range(start='2023-01-01', end='2023-02-15')
df = pd.DataFrame({'Date': dates})


selected_df = select_rows_within_date_range(df)

print(selected_df)
# Out:
#          Date
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05
# 5  2023-01-06
# 6  2023-01-07
# 7  2023-01-08
# 8  2023-01-09
# 9  2023-01-10
# 10 2023-01-11
# 11 2023-01-12
# 12 2023-01-13
# 13 2023-01-14
# 14 2023-01-15
# 15 2023-01-16
# 16 2023-01-17
# 17 2023-01-18
# 18 2023-01-19
# 19 2023-01-20
# 20 2023-01-21
# 21 2023-01-22
# 22 2023-01-23
# 23 2023-01-24
# 24 2023-01-25
# 25 2023-01-26
# 26 2023-01-27
# 27 2023-01-28
# 28 2023-01-29
# 29 2023-01-30
# 30 2023-01-31

# %% [markdown]
# ##### 13)
# The first and foremost necessary library that needs to be imported to use the basic functions of pandas is the Pandas library itself. The Pandas library is a powerful data manipulation and analysis tool, and it provides various data structures and functions to work with structured data, such as DataFrames and Series.
# To import the Pandas library, you can use the following import statement:
# import pandas as pd
# In this import statement, import pandas imports the Pandas library, and as pd provides an alias "pd" to refer to the Pandas library in your code. This is a common convention used by the Pandas community and makes it easier to refer to Pandas functions and objects throughout your code.
#
# Once you have imported the Pandas library, you can use its functions and objects by prefixing them with pd.. For example, you can create a DataFrame using pd.DataFrame(), access columns using df['column_name'], and perform various data manipulation and analysis tasks using the functions provided by Pandas.
